# %% [markdown]
# <a href="https://colab.research.google.com/github/RMoulla/IYT_Septembre/blob/main/Copie_de_TP_Introduction_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Travaux pratiques : Bases de Python**

# %% [markdown]
# ## Première commande

# %%
# Première commande : afficher bonjour
print("Bonjour")
# Out:
# Bonjour

# %% [markdown]
# ## Les différents types de variables

# %%
print(type(4))
print(type(3.14))
print(type("Bonjour"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Assignation

# %%
# La variable a prend la valeur 2

entier = 2
print(entier)
# Out:
# 2

# %%
# Ajouter 1 à entier

entier + 1
# Out:
# 3

# %%
# La variable reel prend la valeur 3

reel = 3.14
print(reel)
# Out:
# 3.14

# %%
# Calculer la somme de entier et reel

entier + reel
# Out:
# 5.140000000000001

# %%
# Définir bonjour comme une chaîne de caractère

bonjour = "Bonjour"
print(bonjour)
# Out:
# Bonjour

# %%
# Définir alice comme une chaîne de caractère

alice = " Alice"
print(alice)
# Out:
#  Alice

# %%
# Calculer le produit entre entier et bonjour

print(entier*bonjour)
# Out:
# BonjourBonjour

# %%
# La somme de bonjour et alice
print(bonjour+alice)
# Out:
# Bonjour Alice

# %%
# Ecraser la valeur d'une variable

alice = " Bob"
print(bonjour + alice)
# Out:
# Bonjour Bob

# %%
# Variable logique

vrai = True
faux = False
print(vrai)
print(faux)
# Out:
# True
# False

# %%
# Somme et produit de deux variables logiques
print(vrai+faux)
print(vrai*faux)
# Out:
# 1
# 0

# %%
# Produit d'une variable logique et d'un nombre

print(vrai*2)
print(faux*2)
# Out:
# 2
# 0

# %%
# Produit d'une variable logique et d'une chaîne de caractère

print(vrai*bonjour)
print(faux*bonjour)
# Out:
# Bonjour

# %% [markdown]
# ## Les conditions

# %%
# si a est supérieur à 1 afficher "a est supérieur à 1"

a = 2
if a > 1:
   print("a est supérieur à 1")
# Out:
# a est supérieur à 1

# %%
# Si a est supérieur à 3 afficher "à supérieur à 3"
# sinon afficher "a est inférieur ou égal à 3"

if a > 3:
    print("a est supérieur à 3")
else:
    print("a est inférieur ou égal à 3")
# Out:
# a est inférieur ou égal à 3

# %%
# Si a est égal à 2 afficher "a est égal à 2"

if a == 2:
    print("a est égal à 2")
# Out:
# a est égal à 2

# %%
# Condition complexe :
# Si a n'est pas égal à 1
# et si a est inférieur à 3
# afficher a est inférieur à 3

if a != 1 and a < 3:
    print("a est inférieur à 3")
# Out:
# a est inférieur à 3

# %%
# Si a est différent de 1
# ou si a est inférieur 0
# afficher "Bonjour"

if a != 1 or a < 0:
    print("Bonjour")
# Out:
# Bonjour

# %%
# Si a est égal à 1 afficher "a est égal à 1"
# sinon si a est inférieur à 1 afficher "a est inférieur à 1"
# sinon si a est supérieur à 1 afficher "a est supérieur à 1"

if a == 1:
  print("a est égal à 1")
elif a < 1:
  print("a est inférieur à 1")
else:
  print("a est supérieur à 1")
# Out:
# a est supérieur à 1

# %%
# Condition avec une chaîne de caractère

char = "Bonjour"

if char:
  print("La chaîne de caractère n'est pas vide")
# Out:
# La chaîne de caractère n'est pas vide

# %%
# Piège de la condition if sur des valeurs nulles

x = 0

if x:
  print("x a une valeur")
else:
  print("x n'a pas de valeur")
# Out:
# x n'a pas de valeur

# %% [markdown]
# ## Boucles itératives `for`

# %%
# Boucle for qui calcule les carrés des nombres de ma_liste

ma_liste = [1, 2, 3, 4, 5]

for iterateur in ma_liste:
  print(iterateur**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
# Boucle for avec range

for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Les listes

# %%
# Définir une liste

ma_liste = [10, 20, 40, 20, 5]

print(ma_liste)
# Out:
# [10, 20, 40, 20, 5]

# %%
# Accéder au premier élément de la liste

ma_liste[0]
# Out:
# 10

# %%
# Accéder au deuxième élément de la liste

ma_liste[1]
# Out:
# 20

# %%
# Accéder au dernier élément de la liste

ma_liste[-1]
# Out:
# 5

# %%
# Accéder à plusieurs éléments en fonction de l'index

ma_liste[1:3]
# Out:
# [20, 40]

# %%
# Modifier un élément d'une liste

ma_liste[0] = 15
print(ma_liste)
# Out:
# [15, 20, 40, 20, 5]

# %%
# Insérer un élément dans une liste

ma_liste.insert(2, 35)
print(ma_liste)
# Out:
# [15, 20, 35, 40, 20, 5]

# %%
# Ajouter un élément à la dernière position

ma_liste.append(20)
print(ma_liste)
# Out:
# [15, 20, 35, 40, 20, 5, 20]

# %%
# Supprimer un élément d'une liste avec pop

ma_liste.pop(2)
print(ma_liste)
# Out:
# [15, 20, 40, 20, 5, 20]

# %%
# Supprimer l'élément 20

ma_liste.remove(20)
print(ma_liste)
# Out:
# [15, 40, 20, 5, 20]

# %%
# Enlever tous les éléments dont la valeur est 20 de la liste
for i in ma_liste:
  if i == 20:
    ma_liste.remove(i)

print(ma_liste)
# Out:
# [15, 40, 5]

# %%
# Ordonner une liste

ma_liste.sort()
print(ma_liste)
# Out:
# [5, 15, 40]

# %%
# Inverser l'ordre des éléments

ma_liste.reverse()
print(ma_liste)
# Out:
# [40, 15, 5]

# %%
# Ordonner une chaine de caractère

char_list = ["Bob", "Alice", "Gargamel"]
char_list.sort()
print(char_list)
# Out:
# ['Alice', 'Bob', 'Gargamel']

# %%
# Ordonner une chaine de caractère selon un critère

char_list.sort(key=len)
print(char_list)
# Out:
# ['Bob', 'Alice', 'Gargamel']

# %%
# Ajouter une liste à une liste liste2 existante

ma_liste.extend(char_list)
print(ma_liste)
# Out:
# [40, 15, 5, 'Bob', 'Alice', 'Gargamel']

# %%
# Référence et copie

ma_copie = ma_liste
print(ma_copie)
# Out:
# [40, 15, 5, 'Bob', 'Alice', 'Gargamel']

# %%
# Enlever le dernier élément de ma_copie

ma_copie.pop()
print(ma_copie)
# Out:
# [40, 15, 5, 'Bob', 'Alice']

# %%
print(ma_liste)
# Out:
# [40, 15, 5, 'Bob', 'Alice']

# %%
# Copier une liste avec copy

ma_copie = ma_liste.copy()
print(ma_copie)
# Out:
# [40, 15, 5, 'Bob', 'Alice']

# %%
ma_copie.pop()
print(ma_copie)
print(ma_liste)
# Out:
# [40, 15, 5, 'Bob']
# [40, 15, 5, 'Bob', 'Alice']

# %%
# Attention : la copie réalisée avec copie est superficielle

list1 = [1, 2, [3, 4]]
list2 = list1.copy()


list2[2][0] = 5

print(list1)
print(list2)
# Out:
# [1, 2, [5, 4]]
# [1, 2, [5, 4]]

# %%
# Copie profonde avec deepcopy

import copy

list1 = [1, 2, [3, 4]]
list2 = copy.deepcopy(list1)

list2[2][0] = 5

print(list1)
print(list2)
# Out:
# [1, 2, [3, 4]]
# [1, 2, [5, 4]]

# %%
# Calculer les carrés d'une liste et sauvegarder dans liste_carre

liste_carre = []

for i in range(1000_000):
  liste_carre.append(i**2)

liste_carre [:5]
# Out:
# [0, 1, 4, 9, 16]

# %%
# Calculer les carrés avec une comprehension de liste

liste_carre = [i**2 for i in range(1000_000)]

print(liste_carre[:5])
# Out:
# [0, 1, 4, 9, 16]

# %%
# Parcourir deux listes

liste1 = [1, 2, 3]
liste2 = ["a", "b", "c"]

for i, j in zip(liste1, liste2):
  print(i, j)
# Out:
# 1 a
# 2 b
# 3 c

# %%
# Parcourir une liste avec enumérate

for i, j in enumerate(liste2):
  print(i, j)
# Out:
# 0 a
# 1 b
# 2 c

# %% [markdown]
# ## Les dictionnaires

# %%
# Définir un dictionnaire avec {}

mon_dict = {"Nom" : "Alice", "Age" : 38, "Ville" : "Lyon"}
print(mon_dict)
# Out:
# {'Nom': 'Alice', 'Age': 38, 'Ville': 'Lyon'}

# %%
# Accéder à la valeur de Age

mon_dict["Age"]
# Out:
# 38

# %%
# Modifier la valeur de l'âge

mon_dict["Age"] = 39
print(mon_dict)
# Out:
# {'Nom': 'Alice', 'Age': 39, 'Ville': 'Lyon'}

# %%
# Ajouter une clé profession

mon_dict["Profession"] = "Ingénieur"
print(mon_dict)
# Out:
# {'Nom': 'Alice', 'Age': 39, 'Ville': 'Lyon', 'Profession': 'Ingénieur'}

# %%
# Récupérer les clés du dictionnaire

mon_obj = mon_dict.keys()
print(mon_obj)
# Out:
# dict_keys(['Nom', 'Age', 'Ville', 'Profession'])

# %%
# Sauvegarder les clés d'un dictionnaire dans une liste
mes_cles = list(mon_dict.keys())
print(mes_cles)
# Out:
# ['Nom', 'Age', 'Ville', 'Profession']

# %%
mes_cles[0]
# Out:
# 'Nom'

# %%
# Sauvegarder les valeurs d'un dictionnaire dans une liste
mes_valeurs = list(mon_dict.values())
print(mes_valeurs)
# Out:
# ['Alice', 39, 'Lyon', 'Ingénieur']

# %%
# Créer un dictionnaire à partir de deux listes

cles = ["Nom", "Age", "Ville"]
valeurs = ["Bob", 42, "Paris"]

bob_dict = dict(zip(cles, valeurs))
print(bob_dict)
# Out:
# {'Nom': 'Bob', 'Age': 42, 'Ville': 'Paris'}

# %% [markdown]
# ## Les dataframes

# %%
# Créer un dataframe

import pandas as pd

df = pd.DataFrame(
    {"Nom" : ["Alice", "Bob", "Sophie"],
     "Age" : [39, 42, 25],
     "Ville" : ["Lyon", "Paris", "Lyon"]
    }
    )
df
# Out:
#       Nom  Age  Ville
# 0   Alice   39   Lyon
# 1     Bob   42  Paris
# 2  Sophie   25   Lyon

# %%
# Afficher les noms des colonnes

df.columns
# Out:
# Index(['Nom', 'Age', 'Ville'], dtype='object')

# %%
# Afficher la dimension du dataframe
df.shape
# Out:
# (3, 3)

# %%
# Afficher les valeurs de la colonne Nom

df['Nom']
# Out:
# 0     Alice
# 1       Bob
# 2    Sophie
# Name: Nom, dtype: object

# %%
# Extraire un sous-dataframe

sub_df = df[['Nom', 'Age']]

sub_df
# Out:
#       Nom  Age
# 0   Alice   39
# 1     Bob   42
# 2  Sophie   25

# %%
# Affichier les deux premières lignes

df.head(2)
# Out:
#      Nom  Age  Ville
# 0  Alice   39   Lyon
# 1    Bob   42  Paris

# %%
# Afficher les deux dernières lignes

df.tail(2)
# Out:
#       Nom  Age  Ville
# 1     Bob   42  Paris
# 2  Sophie   25   Lyon

# %%
# Afficher la première ligne

df.iloc[0]
# Out:
# Nom      Alice
# Age         39
# Ville     Lyon
# Name: 0, dtype: object

# %%
# Afficher les lignes où l'âge est supérieur à 30 ans

df[df['Age'] > 30]
# Out:
#      Nom  Age  Ville
# 0  Alice   39   Lyon
# 1    Bob   42  Paris

# %%
# Afficher les lignes où Ville est Lyon

df[df['Ville'] == "Lyon"]
# Out:
#       Nom  Age Ville
# 0   Alice   39  Lyon
# 2  Sophie   25  Lyon

# %%
# Créer une copie de df
df_copie = df.copy()

# Enlever la colonne Ville de df_copie

df_copie.drop(columns=['Ville'], inplace=True)

# %%
df_copie
# Out:
#       Nom  Age
# 0   Alice   39
# 1     Bob   42
# 2  Sophie   25

# %%
df
# Out:
#       Nom  Age  Ville
# 0   Alice   39   Lyon
# 1     Bob   42  Paris
# 2  Sophie   25   Lyon

# %%
# Sauvegarder df sous format csv

df.to_csv('Mes_donnees.csv')
